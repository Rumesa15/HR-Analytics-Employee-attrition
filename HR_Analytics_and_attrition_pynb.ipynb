# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# Employee attrition poses a significant challenge for n organizations which leads to increased costs and disruption .
#
# Understanding the factors that dives employee turn over is crucial for HR Departments to develop the effective retention stratergies
#
# This project analyzes employee attrition rates by examining  key ayttributes to identify the patterns that influence turnover

# %% [markdown]
# **PROBLEM STATEMENT**:
#
# high employee attrition rate can hinder organisational performance and increase recuritment costs .This project aims to address the following questions
#
#
#
# 1.   What key factors contribute to employee attrition within the organisation ?
# 2.   How can predictive modeling forecast attrition rate ?
#
# 3.What insights  can be derived to enhance HR retention Strategies?
#
# By answering such questions this project gives the insights about the key featureseffecting attrition rate and
# helps HR to Take data-driven decisions

# %% [markdown]
# **IMPORTING NECESSARY LIBRARIES :**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f24b1340-8c08-411f-a5f4-35f363c16f99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f24b1340-8c08-411f-a5f4-35f363c16f99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data= pd.read_csv("Employee data.vsc.csv")

# %% [markdown]
# Displaying information about data set

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %%
if data.isnull().values.any():
    print(data.isnull().sum())
else:
    print("No missing values in the provided dataset")
# Out:
# No missing values in the provided dataset

# %%
data.drop_duplicates(inplace=True)

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# Based on the above steps performed it is cleared that the dataset does not contain any outliers.we can continue our analysis!

# %% [markdown]
# #EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Getting a better understanding of the data through descriptive statistics and visualizations.
# here's an histogram of age distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above histogram it's clear that the age group with the highest frequency is 30-40 years old .The distribution decreases for age groups of both younger and older than that .

# %% [markdown]
#  2.calculating attrition rate of the employee

# %%
attrition_rate=data['Attrition'].value_counts(normalize=True)*100
print(f"Attrition Rate:{attrition_rate[1]:.2f}%")
# Out:
# Attrition Rate:16.12%
# <ipython-input-25-51bc497c4072>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Attrition Rate:{attrition_rate[1]:.2f}%")

# %% [markdown]
# The attrition rate of the employees is approximately 16.12%.This indicates that over 16 out of every employee have left the company.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x=data.Attrition)
plt.title('Attrition Distribution')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# By visualization of the data it is shown that there is less number of  employees who leaves  the organisation i.e only less number of employees leaves the company voluntrily or involuntrily

# %% [markdown]
# Now let us take a look over what factors influences attrition rate

# %% [markdown]
# #DATA VISUALIZATION

# %% [markdown]
# 1.DEPARTMENT and ATTRITION

# %%
sns.countplot(x='Department',hue='Attrition',data=data)
plt.title('Department vs Attrition')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The above bar graph presents the attrition rates for three key departments , i.e SALES DEPARTMENT ,RESEARCH and DEVOLEPMENT DEPARTMENT and HUMAN RESOURCE DEPARTMENT
# 1.SALES DEPARTMENT : Attrition rate  (Yes) is approximately 200 employees and Attrition rate (No) is approximately 400 employees
#
# 2.RESEARCH & DEVELOPMENT DEPARTMENT:
# Attrition rate (Yes) is approximately 300 of employeees and Attrition rate(No) is approximately 800 of employees from the organisation
#
# 3.HUMAN RESOURCES DEPARTMENT:
# Attrition  rate (yes) is approximtely 100 employees and Attrition rate  (No) is approximately 200 employees
#
# REPORT:
# The research and development department has the highest number of employees both leaving and staying , both indicating a high overall headcount with significant Turn  over rate
#
# The sales department has a noteable attrition rate,with 200 out of 600 employees leaving
#
# The human Resources department has the lowest attrition

# %% [markdown]
# 2.GENDER AND ATTRITION

# %%
import matplotlib.pyplot as plt
attrition_counts=data['Attrition'].value_counts()
labels=attrition_counts.index
sizes=attrition_counts.values
colors=['pink','blue']
explode=(0.1,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',startangle=90)
plt.axis('equal')
plt.title('Attrition Rate by Gender')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above  pie chart shows that 83.9% of the employees did not experience attrition, and 16.1% did .

# %% [markdown]
# 3.EDUCATION FIELD AND ATTRITION :

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='EducationField',hue='Attrition',data=data)
plt.title('Education Field vs Attrition')
plt.xlabel('Education Field')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# from the above plot we conclude that employees with Life sciences educational field has the higher rate of attrition yes and the employees of Human resources educational background has least Attrition from all the other educational fields

# %% [markdown]
# 4.OVERTIME AND ATTRITION

# %%
sns.countplot(hue=data.Attrition,x=data.OverTime)
plt.title('Overtime vs Attrition')
plt.xlabel('Overtime')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# From the above visualization there is very less attrition based on the overtime or not so here overtime feature is not effecting much to our attrition rate

# %% [markdown]
# 5.JOB ROLE AND ATTRITION:

# %%
attrition_count=data[data['Attrition']=='Yes']['JobRole'].value_counts()
plt.figure(figsize=(12,8))
plt.pie(attrition_count,labels=attrition_count.index,startangle=140)
plt.title('Attrition by job role(yes)')
plt.axis('equal')
plt.show()
attrition_no_count=data[data['Attrition']=='No']['JobRole'].value_counts()
plt.figure(figsize=(12,8))
plt.pie(attrition_no_count,labels=attrition_no_count.index,startangle=140)
plt.title('Attrition by job role(no)')
plt.axis('equal')
# Out:
# (-1.0999999866715517,
#  1.0999998269160698,
#  -1.099992667185981,
#  1.099999650362987)

# %% [markdown]
# By the above pie charts 1. Attrition by job role(Yes) shows the major job roles for attrition rate yes is Research Scientist,lAB Technician ,Sales executives
# we can say thatJob role of the employees will manually effect the attrition rate of the  employee

# %% [markdown]
# 6.BUSINESS TRAVEL and ATTRITION

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='BusinessTravel',y='Attrition',data=data,estimator=lambda x: len(x)/len(data)*100)
plt.title('Business Travel vs Attrition')
plt.xlabel('Business Travel Frequency')
plt.ylabel('Attrition rate (%)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# It is clear that the employees who travel frequently have the highest attrition rate , where as non-travel employees have the lowest  .
# This shows that frequent travel may be significant factor contributing to attrition

# %% [markdown]
# 7.MARITAL STATUS AND ATTRITION

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='MaritalStatus',hue='Attrition',data=data)
plt.title('Marital Status vs Attrition')
plt.xlabel('Marital Status')
# Out:
# Text(0.5, 0, 'Marital Status')

# %% [markdown]
# This shows that the single employees tend to have higher attrition rates compared to married or divorced employees

# %% [markdown]
# 8.PERCENT SALARY HIKEAND ATTRITIOIN

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition',y='PercentSalaryHike',data=data)
plt.title('Percent Salary Hike vs Attrition')
plt.xlabel('Attrition')
plt.ylabel('Percent Salary Hike')
plt.show()

# %% [markdown]
# This demonstrates that larger percent salary hikes are generally associated with lower attrition rates . This salary increase can play a key role in analysis

# %% [markdown]
# 9.PERFORMANCE RATING AND ATTRITION

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='PerformanceRating',hue='Attrition',data=data)
plt.title('Performance Rating vs Attrition')
plt.xlabel('Performance Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# FRom this we can say that employees with higher performance ratings tend to exhibit lower attrition rates

# %% [markdown]
# 10.YEARS AT COMPANY AND ATTRITION

# %%
sns.boxplot(x='Attrition',y='YearsAtCompany',data=data)
plt.title('Years at Company vs Attrition')
plt.xlabel('Attrition')
plt.ylabel('Years at Company')
# Out:
# Text(0, 0.5, 'Years at Company')

# %% [markdown]
# This shows that the employees who leaves the company tend to have fewer years at company compared to those who stays
# This is the key value for analyzing the attrition rate of the company

# %% [markdown]
# Now we have got some kind of idea about the features which is affecting the attriton rate so here comes the enxt step of model evaluation for model evaluation we need to have all the variables in the numerical form but here we have some set of categorical data so we are now converting the categorical data by one-hot encoding or iloc or map function
# Let us here use Map function for handling CATEGORICAL DATA

# %% [markdown]
# **HANDLING CATEGORICAL DATA**
# Here is the list of categorical data which is affecting the employees attrition rate
#
#  1.Attrition
#
# 2.Department
#
# 3.JobRole
#
# 4.Gender
#
# 5.BusinessTravel
#
# 6.EducationField
#
# 7.OverTime
#
# 8.MaritalStatus
#
# so here i am using map() Function for converting the categorical data for the machine learning model as it cannot take categorical variables as input

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-93981a53b600> in <cell line: 1>()
# ----> 1 pd.load(data)
#
# NameError: name 'pd' is not defined

# %%
data.Attrition=data.Attrition.map({'Yes':1,'No':0})

# %%
data.BusinessTravel=data.BusinessTravel.map({'Travel_Rarely':2,'Travel_Frequently':1,'Non-Travel':0})

# %%
data.Department=data.Department.map({'Research & Department':2,'Human Resources':0,'Sales':1})

# %%
data.JobRole=data.JobRole.map({'Manager':1,'Healthcare Representative':3,'Sales Executive':2,'Laboratory Technician':4,'Human Resources':5,'Research Scientist':6,'Sales Representative':7,'Research Director':8})

# %%
data.Gender=data.Gender.map({'Female':1,'Male':0})

# %%
data.MaritalStatus=data.MaritalStatus.map({'divorced':0,'married':2,'single':0})

# %%
data.EducationField=data.EducationField.map({'Medical':1,'Technical Degree':2,'Laboratory Technician':3,'Manufacturing Director':4,'Human Resources':5,'Other':6,'Life Sciences':7})

# %%
data.OverTime=data.OverTime.map({'No':0,'Yes':1})

# %% [markdown]
# Now we have done the part of handling categorical data which i am considering to use in my model
# Now let us take a look over the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                0 non-null      float64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1311 non-null   float64
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# We can see that the data features i was considering to use for my model has been successfully converted to the integer format and it is no more in the categorical data

# %% [markdown]
# Now i am dropping the unique values which is not necessary for my model and i am not considering it

# %%
data.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1,inplace=True)

# %% [markdown]
# # MODEL SELECTION

# %% [markdown]
# USING RANDOM FOREST CLASSIFIER

# %% [markdown]
# Importing the necessary libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x=data.drop(columns=['Attrition'])
y=data['Attrition']

# %%
x_train, x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
model.fit(x_train , y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
conf_matrix = confusion_matrix(y_test,y_pred)
class_report= classification_report(y_test,y_pred)

# %%
print(f"Accuracy: {accuracy * 100:.2f}%")
print("Confusion Matrix:")
print(confusion_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 87.07%
# Confusion Matrix:
# <function confusion_matrix at 0x7db4575976d0>
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       255
#            1       0.60      0.08      0.14        39
#
#     accuracy                           0.87       294
#    macro avg       0.74      0.53      0.53       294
# weighted avg       0.84      0.87      0.82       294

# %% [markdown]
# As here this model acheived an 87.07% accuracy showing strong performance for predicting the majority classes with high precision and recall
# and it struggles with minority class with lower precision and recall  so we need to do tuning for the imbalanced data

# %% [markdown]
# Under sampling  reduces the number of samples in the majority class

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
x_train_rus = imputer.fit_transform(x_train_rus)
x_test = imputer.transform(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:598: UserWarning: Skipping features without any observed values: ['Department' 'MaritalStatus']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:598: UserWarning: Skipping features without any observed values: ['Department' 'MaritalStatus']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
x_train_rus,y_train_rus= rus.fit_resample(x_train,y_train)
print(y_train_rus.value_counts())
# Out:
# Attrition
# 0    198
# 1    198
# Name: count, dtype: int64

# %% [markdown]
# Now trying Gradient boosting model

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.impute import SimpleImputer
x_train_rus= pd.DataFrame(x_train_rus)
x_test = pd.DataFrame(x_test)

imputer = SimpleImputer(strategy='mean')
x_train_rus = imputer.fit_transform(x_train_rus)
x_test = imputer.transform(x_test)

gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(x_train_rus,y_train_rus)
y_pred_gb = gb_model.predict(x_test)
accuracy_gb = accuracy_score(y_test,y_pred_gb)
conf_matrix_gb = confusion_matrix(y_test,y_pred_gb)
class_report_gb = classification_report(y_test,y_pred_gb)
print(f" Gradient Boosting Accuracy: {accuracy_gb * 100:.2f}%")
print("Confusion Matrix:")
print(conf_matrix_gb)
print("Classification Report:")
print(class_report_gb)
# Out:
#  Gradient Boosting Accuracy: 71.77%
# Confusion Matrix:
# [[186  69]
#  [ 14  25]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.82       255
#            1       0.27      0.64      0.38        39
#
#     accuracy                           0.72       294
#    macro avg       0.60      0.69      0.60       294
# weighted avg       0.84      0.72      0.76       294

# %% [markdown]
# # REPORT

# %% [markdown]
# This project aimed to analyze the factors influencing employee attrition rates and to develop predictive models
#
# Then analysis identifies several key featuress from the data set that impactes attritionj rates is
#
#
#
# *   DEPARTMENT:different departments exhibited varying attrition rates
#
#  The research and development department has the highest number of employees both leaving and staying , both indicating a high overall headcount with significant Turn over rate
#
#  The human Resources department has the lowest attrition
#
#
# *  GENDER :  83.9% of the employees did not experience attrition, and 16.1% did .
#
#
# *   EDUCATION FIELD :employees with Life sciences educational field has the higher rate of attrition yes and the employees of Human resources educational background has least Attrition from all the other educational fields
#
# *   OVERTIME : there is very less attrition based on the overtime or not so here overtime feature is not effecting much to our attrition rate
#
# *   JOB ROLE : Attrition by job role(Yes) shows the major job roles for attrition rate yes is Research Scientist,lAB Technician ,Sales executives we can say thatJob role of the employees will manually effect the attrition rate of the employee
# *   BUSINESS TRAVEL : employees who travel frequently have the highest attrition rate , where as non-travel employees have the lowest . This shows that frequent travel may be significant factor contributing to attrition
#
# *   MARITAL STATUS : the single employees tend to have higher attrition rates compared to married or divorced employees
# *  PERCENT SALARY HIKE :larger percent salary hikes are generally associated with lower attrition rates . This salary increase can play a key role in analysis
#
# * PERFORMANCE RATING : employees with higher performance ratings tend to exhibit lower attrition rates
# * YEARS AT COMPANY : the employees who leaves the company tend to have fewer years at company compared to those who stays This is the key value for analyzing the attrition rate of the company

# %% [markdown]
# Using a random forest classifier , we achieved  an F- score of 93% and an accuracy of 87% , confirming the model's ability to predict employee turnover based on some features explored
#
# additionally, after experimenting with sampling techniques and a gradient boosting model , the accuracy decreased to 71.77% , indicating the importace of model selection and preprocessing
#
# Over all , this analysis provides actionable insights for HR develop targeted retention strategies based on the identified factors
# Future work could involve refining predictive models and exploring addtional data sources to enhance accuracy further.
